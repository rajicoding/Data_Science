# %% [markdown]
# # Importing the libraries

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %% [markdown]
# # Importing the dataset

# %%
dataset=pd.read_csv("Placement.csv")
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
#shape:Number of rows and nummber of columns
print(dataset.shape)
print("The number of row:",dataset.shape[0])
print("The number of column:",dataset.shape[1])
# Out:
# (215, 15)
# The number of row: 215
# The number of column: 15

# %% [markdown]
# # Univariate analysis

# %%
sns.distplot(dataset["ssc_p"],hist=True,kde=True,kde_kws={'color':'red'})
# Out:
# C:\Users\Inst_\AppData\Local\Temp\ipykernel_2028\963159319.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset["ssc_p"],hist=True,kde=True,kde_kws={'color':'red'})
# <Axes: xlabel='ssc_p', ylabel='Density'>

# %%
# from the above plot we can say that there is no repetitions in ssc_p marks from 30 to 40 and 90 to 100 range
# ssc_p marks from 60 to 65 have higher density as per the graph

# %% [markdown]
# # Bivariate Analysis

# %%
sns.jointplot(x='ssc_p',y='salary',data=dataset)
plt.show()

# %%
# Students with ssc_p marks ranging from 50 to 90 are getting salary from 2,00,000 to 4,00,000
# Few students(5 of them) with ssc_p marks ranging from 65 to 75 are getting salary from 5,00,000 to 7,00,000
# one student with ssc_p marks as 62 is getting salary greater than 9,00,000(this might be an outlier for the dataset)

# %%
sns.jointplot(x='ssc_p',y='salary',data=dataset,kind='hex')
plt.show()

# %%
# Top most frequency(dark color hex)
# There are more repetitions for ssc_p marks from 63 to 65
# More repetitions for salary from 2,30,000 to 2,70,000 approximately
# Second top most frequency(light color compared to top most)
# There are repetitions for ssc_p marks from 72 to 74
# There are repetitions for salary from 2,10,000 to 2,40,000 approximately
# Third top most frequency(light color compared to second top most)
# There are repetitions for ssc_p marks from 57-62, 66-70,73-77,80-86
# There are repetitions for salary from 2,10,000 to 3,10,000

# %%
sns.jointplot(x='ssc_p',y='salary',data=dataset,kind='kde')
plt.show()

# %%
#There are more repetitions in the SSC_P marks, which range from 48 to 94 approximately
#There are more repetitions in the Salary range from 1,00,000 to 5,00,000 approximately
#There are a few repetitions in the salary range from 6,50,000 to 7,50,000

# %%
# Pair Plot
sns.pairplot(dataset,hue='gender',diag_kind='kde',kind='scatter',palette='husl')
plt.show()

# %% [markdown]
# # For Categorical Plot

# %%
sns.stripplot(x='ssc_b',y='ssc_p',data=dataset)
plt.show()

# %%
# Students of ssc_b(central)  scored marks from 41 to 88
# Students of ssc_b(Others), scored marks from 41 to 89
# Most of the students in ssc_b(central) are scored marks from 52 to 80
# Most of the students in ssc_b(others) are scored marks from 50 to 85

# %%
sns.stripplot(x='gender',y='ssc_p',data=dataset,jitter=True)
plt.show()

# %%
# Most of the male students scored ssc_p marks ranging from 50 to 85
# Most of the female students scored ssc_p marks ranging from 58 to 80

# %%
# importance of swarmplot
#Swarmplot is similar to stripplot but the difference is avoids overlap which clearly shows the distribution of values in the plot
# It is usuallly grouped with box plot which is called as beeswarm

# %%
sns.swarmplot(x='gender',y='ssc_p',data=dataset)
plt.show()

# %%
# Most of the male students get 62 marks in SSC
# Most of the female students get 74 marks in SSC

# %%
sns.swarmplot(x='gender',y='ssc_p',hue='ssc_b',data=dataset)
plt.show()

# %%
sns.swarmplot(x='gender',y='ssc_p',hue='ssc_b', data=dataset,dodge=True)
plt.show()

# %%
# Most of the male students in ssc_b(Central) scored 62 marks in SSC
# Most of the male students in ssc_b(others) scored 68 marks in SSC
# Most of the female students in ssc_b(Central) scored 70 marks in SSC
# Most of the female students in ssc_b(others) scored 75 marks in SSC

# %%
sns.swarmplot(x='gender',y='ssc_p',hue='ssc_b', linewidth=1, data=dataset)
plt.show()

# %% [markdown]
# # Distribution Observation

# %%
sns.violinplot(x='gender',y='ssc_p',data=dataset)
plt.show()

# %%
# Most of the male students scored from 60 to 74 in SSC
# Most of the female students scored from 62 to 78 in SSC
# Minimum and maximum marks of male students in SSC are 34 and 97 respectively
# Minimum and maximum marks of female students in SSC are 32 and 97 respectively

# %%
sns.violinplot(x='hsc_b',y='hsc_p', data=dataset, hue='gender')
plt.show()

# %%
# Male students in hsc_b(Others),scored marks from 60 to 78 in hsc_p
# Female students in hsc_b(Others),scored marks from 58 to 78 in hsc_p
# Male students in hsc_b(Central), scored marks from 60 to 78 in hsc_p
# female students in hsc_b(Central), scored marks from 62 to 78 in hsc_p
# Maximum marks and minimum marks obtained by male students in hsc_b(Others) is 150 and 30 respectively
# Maximum marks obtained by female students in hsc_b(Others) is 160 and 20 respectively
# Maximum marks and minimum marks obtained by male students in hsc_b(Others) is 90 and 20 respectively
# Maximum marks and minimum marks obtained by female students in hsc_b(Central) is 95 and 30 respectively

# %%
sns.violinplot(x='specialisation',y='salary', data=dataset, hue='gender')
plt.show()

# %%
# Male students with Mkt and HR specialisation received salary from 2,10,000 to 3,00,000
# Female students with Mkt and HR specialisation received salary from 2,00,000 to 2,50,000
# Male students with Mkt and fin specialisation received salary from 2,40,000 to 3,00,000
# Female students with Mkt and fin specialisation received salary from 2,10,000 to 3,00,000
# Minimum and maximum marks obtained by male students(Mkt & HR specialisation) are 1,50,000 and 5,00,000 respectively
# Minimum and maximum marks obtained by male students(Mkt & fin specialisation) are 50,000 and 10,00,000 respectively
# Minimum and maximum marks obtained by female students(Mkt & HR specialisation) are 1,60,000 and 4,00,000 respectively
# Minimum and maximum marks obtained by male students(Mkt & fin specialisation) are 1,00,000 and 7,50,000 respectively

# %%
sns.boxplot(x='ssc_b', y='ssc_p',data=dataset,hue='ssc_b')
plt.show()

# %%
# Minimum and maximum marks of students in ssc_b(Others) is 42 and 89 respectively
# 25%(Q1) of the students in ssc_b(Others) scored 62 marks in SSC
# 50%(Q2) of the students in ssc_b(Others) scored 69 marks in SSC
# 75%(Q3) of the students in ssc_b(Others) scored 78 marks in SSC
# Minimum and maximum marks of students in SSC_b(Central) is 42 and 88 respectively
# 25%(Q1) of the students in ssc_b(Central) scored 61 marks in SSC
# 50%(Q2) of the students in ssc_b(Central) scored 65 marks in SSC
# 75%(Q3) of the students in ssc_b(Central) scored 73 marks in SSC
# Overall SSC_b(Others) Students are performing well compared to SSC_B(Central) Students

# %%
sns.boxplot(x='ssc_b', y='ssc_p',data=dataset,hue='gender')
plt.show()

# %%
# Lower bound outlier value for SSC_B(Others) is 42 marks
# Minimum and maximum marks of male students in SSC_B(Others) is 49 and 89 respectively
# 25%(Q1) of male students in SSC_B(Others) scored 62 marks 
# 50%(Q2) of male students in SSC_B(Others) scored 67 marks
# 75%(Q3) of male students in SSC_B(others) scored 76 marks
# Minimum and maximum marks of female students in SSC_B(others) is 45 and 86 respectively
# 25%(Q1) of female students in SSC_B(Others) scored 65 marks 
# 50%(Q2) of female students in SSC_B(Others) scored 74 marks
# 75%(Q3) of female students in SSC_B(others) scored 78 marks
# Minimum and maximum marks of male students in SSC_B(Central) is 42 and 87 respectively
# 25%(Q1) of male students in SSC_B(Others) scored 60 marks 
# 50%(Q2) of male students in SSC_B(Others) scored 65 marks
# 75%(Q3) of male students in SSC_B(others) scored 73 marks
# Minimum and maximum marks of female students in SSC_B(Central) is 43 and 87 respectively
# 25%(Q1) of female students in SSC_B(Others) scored 61 marks 
# 50%(Q2) of female students in SSC_B(Others) scored 67 marks
# 75%(Q3) of female students in SSC_B(others) scored 75 marks
# Overall, Students with SSC_B(Other) are performing well compared to Students with SSC_B(Central)
# In SSC_B(Others), Male students performed well compared to Female
# In SSC_B(Others), Female students perform well compared to male students.(percentile-wise)

# %%
sns.barplot(x='ssc_b', y='ssc_p', data=dataset, hue='gender')
plt.show()

# %%
# female students performed well in SSC_B(Others) and SSC_B(central) compared to Male students
# Students in SSC_B(Others) performed well compared to SSC_B(Central)

# %%
sns.countplot(x='ssc_b', data=dataset, hue='gender')
plt.show()

# %%
# More number of Male students are available in both SSC_B(Others and Central) compared to female students
# Most of the students belongs to ssc_b(Central) compared to SSC_B(Oters)

# %%
sns.pointplot(x='ssc_p',y='hsc_b',data=dataset,hue='gender')
plt.show()

# %%
#A pointplot is a type of plot commonly used in data visualization to 
#show the mean (or other estimator) of a variable along with a confidence interval, often across categories.

# %%
sns.pointplot(x='hsc_b',y='ssc_p',data=dataset,hue='gender')
plt.show()

# %%
sns.pointplot(x='hsc_b',y='ssc_p',data=dataset,hue='gender',dodge=True)
plt.show()

# %%
sns.boxplot(data=dataset, orient='h')
plt.show()

# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
df=sns.load_dataset('exercise')
sns.catplot(x='time',y='pulse',hue='kind',kind='violin' ,col='diet',data=df);
plt.show()

# %%
# The above plot depicts the relationship for time vs pulse for people who exercise with different diet plans(low-fat and no-fat diet)
# Pulse is captured for the people while taking rest, walking and running for three different timelines - 1min, 15 min and 30 min 
# First plot(diet=no fat)
# Observations:diet-no fat for 1 min duration:
# Minimum pulse rate and maximum pulse rate for people while resting for a minute are 40 and 110 
# Most of the people while resting for a minute have a pulse rate from 86 to 98 
# 25% of the people while resting for a minute have a pulse rate of 86 
# 50% of the people while resting for a minute have a pulse rate of 92 
# 75% of the people while resting for a minute have a pulse rate of 98 
# Minimum pulse rate and maximum pulse rate for people while walking for a minute are 40 and 114 respectively
# Most of the people while walking for a minute have a pulse rate of 96 to 106
# 25% of the people while walking for a minute have a pulse rate of 91 
# 50% of the people while walking for a minute have a pulse rate of 96 
# 75% of the people while walking for a minute have a pulse rate of 104 
# Minimum pulse rate and maximum pulse rate for people while running for a minute are 88 and 108 respectively
# Most of the people while running for a minute have a pulse rate of 94 to 104
# 25% of the people while running for a minute have a pulse rate of 94
# 50% of the people while running for a minute have a pulse rate of 99
# 75% of the people while running for a minute have a pulse rate of 102 
# Overall Observation:
# People have a normal pulse rate while resting, walking and running for a minute
# People who walk and rest for a minute have a lower pulse rate(40) compared to those who run for a minute(based on min value)
# Some people who walk for a minute have a higher pulse rate(114) compared to those who run or rest for a minute(based on max value)
# People who run for a minute have pulse rates greater than or equal to 88 whereas those who walk or rest have lower pulse rates(40)

# %%
# Observations:diet-no fat for 15 min duration:
# Minimum pulse rate and maximum pulse rate for people while resting for 15 minutes are 40 and 108 
# Most of the people while resting for 15 minutes have a pulse rate from 92 to 102 
# 25% of the people while resting for 15 minutes have a pulse rate of 86 
# 50% of the people while resting for 15 minutes have a pulse rate of 94 
# 75% of the people while resting for 15 minutes have a pulse rate of 98 
# Minimum pulse rate and maximum pulse rate for people while walking for 15 minutes  are 40 and 120 respectively
# Most of the people while walking for 15 minutes have a pulse rate of 94 to 108
# 25% of the people while walking for 15 minutes have a pulse rate of 91 
# 50% of the people while walking for 15 minutes have a pulse rate of 96 
# 75% of the people while walking for 15 minutes have a pulse rate of 104 
# Minimum pulse rate and maximum pulse rate for people while running for 15 minutes are 98 and 146 respectively
# Most of the people while running for 15 minutes have a pulse rate of 120 to 132
# 25% of the people while running for 15 minutes have a pulse rate of 122
# 50% of the people while running for 15 minutes have a pulse rate of 126
# 75% of the people while running for 15 minutes have a pulse rate of 128 
# Overall observation:
# people have a normal pulse rate while resting, walking for 15 minutes compared to people who run for 15 minutes
# Some of them who run for 15 minutes have a higher pulse rate(146) compared to those who walk and rest
# People who walk and rest for 15 minutes have a lower pulse rate(40) compared to those who run

# %%
# Observations:diet-no fat for 30 min duration:
# Minimum pulse rate and maximum pulse rate for people while resting for 30 minutes are 60 and 108 
# Most of the people while resting for 30 minutes have a pulse rate from 90 to 102 
# 25% of the people while resting for 30 minutes have a pulse rate of 90 
# 50% of the people while resting for 30 minutes have a pulse rate of 96 
# 75% of the people while resting for 30 minutes have a pulse rate of 98 
# Minimum pulse rate and maximum pulse rate for people while walking for 30 minutes  are 78 and 112 respectively
# Most of the people while walking for 30 minutes have a pulse rate of 96 to 104
# 25% of the people while walking for 30 minutes have a pulse rate of 88 
# 50% of the people while walking for 30 minutes have a pulse rate of 100 
# 75% of the people while walking for 30 minutes have a pulse rate of 102 
# Minimum pulse rate and maximum pulse rate for people while running for 30 minutes are 120 and 160 respectively
# Most of the people while running for 30 minutes have a pulse rate of 138 to 144
# 25% of the people while running for 30 minutes have a pulse rate of 140
# 50% of the people while running for 30 minutes have a pulse rate of 141
# 75% of the people while running for 30 minutes have a pulse rate of 144
#Overall observation:
# people have a normal pulse rate while resting, walking for 30 minutes compared to people who run for 30 minutes
# Some of them who run for 30 minutes have a higher pulse rate(160) compared to those who walk or rest
# Some of them who rest have a lower pulse rate(60) compared to those who walk or run
# Pulse rate of people who run for 15 minutes and 30 minutes with a no-fat diet is abnormal(i.e > 120)
# Pulse rate of people who rest or walk for 1 min,15 min and 30 minutes with a no-fat diet is normal(within 120)

# %%
# Right plot(diet=low fat)
# Observations:diet-low fat for 1 min duration:
# Minimum pulse rate and maximum pulse rate for people while resting for a minute are 30 and 106
# Most of the people while resting for 1 minute have a pulse rate from 84 to 96
# 25% of the people while resting for a minute have a pulse rate of 84 
# 50% of the people while resting for a minute have a pulse rate of 90 
# 75% of the people while resting for a minute have a pulse rate of 92 
# Observations:diet-low fat for 15 min duration:
# Minimum pulse rate and maximum pulse rate for people while walking for a minute are 82 and 100 respectively
# Most of the people while walking for a minute have a pulse rate of 86 to 96
# 25% of the people while walking for a minute have a pulse rate of 88 
# 50% of the people while walking for a minute have a pulse rate of 90 
# 75% of the people while walking for a minute have a pulse rate of 94 
# Observations:diet-low fat for 30 min duration:
# Minimum pulse rate and maximum pulse rate for people while running for a minute are 81 and 104 respectively
# Most of the people while running for a minute have a pulse rate of 92 to 98
# 25% of the people while running for a minute have a pulse rate of 92
# 50% of the people while running for a minute have a pulse rate of 94
# 75% of the people while running for a minute have a pulse rate of 98 
# Overall observation:
# people have a normal pulse rate while resting, walking and running for a minute
# People who rest for a minute have a much lower pulse rate(30) compared to those who run,walk for a minute(based on min value)
# People who rest for a minute have a higher pulse rate(106) compared to those who run,rest for a minute(based on max value)

# %%
# Observations:diet-low fat for 15 min duration:
# Minimum pulse rate and maximum pulse rate for people while resting for 15 minutes are 40 and 106 
# Most of the people while resting for 15 minutes have a pulse rate of 88 to 96 
# 25% of the people while resting for 15 minutes have a pulse rate of 85 
# 50% of the people while resting for 15 minutes have a pulse rate of 92 
# 75% of the people while resting for 15 minutes have a pulse rate of 94 
# Minimum pulse rate and maximum pulse rate for people while walking for 15 minutes  are 60 and 112 respectively
# Most of the people while walking for 15 minutes have a pulse rate of 92 to 97
# 25% of the people while walking for 15 minutes have a pulse rate of 90 
# 50% of the people while walking for 15 minutes have a pulse rate of 95 
# 75% of the people while walking for 15 minutes have a pulse rate of 96 
# Minimum pulse rate and maximum pulse rate for people while running for 15 minute are 78 and 150 respectively
# Most of the people while running for 15 minutes have a pulse rate of 102 to 112
# 25% of the people while running for 15 minutes have a pulse rate of 104
# 50% of the people while running for 15 minutes have a pulse rate of 106
# 75% of the people while running for 15 minutes have a pulse rate of 110
# Overall observations:
# people have a normal pulse rate while resting, walking and running for 15 minutes
# People who run for 15 minutes have a higher pulse rate(150) compared to those who walk or rest(based on max value)
# People who rest have a lower pulse rate(40) compared to those who run or walk for 15 minutes

# %%
# Observations:diet-no fat for 30 min duration:
# Minimum pulse rate and maximum pulse rate for people while resting for 30 minutes are 58 and 102
# Most of the people while resting for 30 minutes have a pulse rate of 88 to 94
# 25% of the people while resting for 30 minutes have a pulse rate of 86
# 50% of the people while resting for 30 minutes have a pulse rate of 92 
# 75% of the people while resting for 30 minutes have a pulse rate of 94 
# Minimum pulse rate and maximum pulse rate for people while walking for 30 minutes  are 40 and 114 respectively
# Most of the people while walking for 30 minutes have a pulse rate of 92 to 104
# 25% of the people while walking for 30 minutes have a pulse rate of 92 
# 50% of the people while walking for 30 minutes have a pulse rate of 96 
# 75% of the people while walking for 30 minutes have a pulse rate of 100 
# Minimum pulse rate and maximum pulse rate for people while running for 30 minute are 86 and 130 respectively
# Most of the people while running for 30 minutes have a pulse rate of 108 to 120
# 25% of the people while running for 30 minutes have a pulse rate of 108
# 50% of the people while running for 30 minutes have a pulse rate of 110
# 75% of the people while running for 30 minutes have a pulse rate of 116 
# Overall Observations:
# people have a normal pulse rate while resting, walking for 30 minutes compared to people who run for 30 minutes
# People who run for 30 minutes have a higher pulse rate(130) compared to those who walk or rest
# People who walk for 30 minutes have a lower pulse rate(40) compared to those who rest or run
# Pulse rate of people who run for 15 minutes and 30 minutes with diet-low fat is abnormal(.i.e > 120)
# Pulse rate of people who rest or walk for 1 min,15 min and 30 minutes with diet- low fat is within normal range(within 120)

# %%
# Left plot: diet-no fat
# Overall Observation:1 min
# People who rest, walk and run for a minute have a normal pulse rate(within normal range<120)
# People who walk, rest for a minute have a lower pulse rate compared to those who run for a minute(based on min value)
# People who walk for a minute have a higher pulse rate(114) compared to those who run and rest for a minute(based on max value)
# People who run for a minute have higher pulse rates starting from 88 whereas those who walk or rest have lower pulse rates(40) 
# Overall observation:15 min
# people have a normal pulse rate while resting, walking for 15 minutes compared to those who run for 15 minutes
# People who run for 15 minutes have a higher pulse rate(146) compared to those who walk or rest
# People who walk, rest for 15 minutes have a lower pulse rate(40) compared to those who run
#Overall observation:30 min
# people have a normal pulse rate while resting, walking for 30 minutes compared to people who run for 30 minutes
# People who run for 30 minutes have a higher pulse rate(160) compared to those who walk and rest
# People who rest have a lower pulse rate(60) compared to those who walk and run
# Observations for exercising with a no-fat diet for different time intervals:
# Pulse rate of people who rest, walk and run for 1 min with a diet-no fat is normal(within 120)
# Pulse rate of some people who run for 15 minutes and 30 minutes with a no-fat diet is abnormal(i.e. > 120)
# Pulse rate of people who rest and walk for 15 minutes and 30 minutes with a no-fat diet is within the normal range(within 120)
# when the time duration increases(15 min,30 min) for running, the pulse rate of people following a no-fat diet plan is getting abnormal(i.e>120)
# So a no-fat diet is not suitable for some people to do running greater than 1 minute
# Further observations to be done on the people with respect to their health conditions for more details.
#Right plot: diet-low fat
# Overall observation:1 min
# people have a normal pulse rate while resting, walking and running for a minute
# People who rest for a minute have a much lower pulse rate(30) compared to those who run for a minute(based on min value)
# People who rest for a minute have a higher pulse rate(106) compared to those who run,walk for a minute(based on max value)
# Overall observations: 15 min
# people have a normal pulse rate while resting, walking for 15 minutes compared to people who run for 15 minutes
# People who run for 15 minutes have a higher pulse rate(150) compared to those who walk and rest(based on max value)
# People who rest have a lower pulse rate(40) compared to those who run and walk for 15 minutes
# Overall Observations:30 min
# people have a normal pulse rate while resting, walking for 30 minutes compared to people who run for 30 minutes
# People who run for 30 minutes have a higher pulse rate(130) compared to those who walk and rest
# People who walk for 30 minutes have a lower pulse rate(40) compared to those who rest and run
# Observations for exercising with a low-fat diet for different time intervals:
# Pulse rate of some people who run for 15 minutes and 30 minutes with a low-fat diet is abnormal(.i.e. > 120)
# Pulse rate of people who rest, walk and run for 1 min with a low-fat diet is normal(within 120)
# Pulse rate of people who rest and walk for 15 minutes and 30 minutes with a low-fat diet is normal(within 120)
# Pulse rate of some people who walk for 30 minutes is lower(40) compared to those who rest and run
# Pulse rate of some people who rest for a minute is lower(30) compared to those who run and walk 
# When the time duration increases (15 min,30 min) for running, the pulse rate of people following a low-fat diet plan becomes abnormal(i.e. >120)
# Observations for diet-no fat and diet-low fat:
# Both of the categories(diet-no fat and diet-low fat) people have a normal pulse while resting, walking and running for a minute
# People who follow a low-fat diet have a lower pulse spike rate(130) while running for 30 minutes compared to those(160) who follow a no-fat diet.
# People who follow a low-fat diet have a higher pulse spike rate(150) while running for 15 minutes compared to those(146) who follow a no-fat diet.
# Low-fat diet is quite suitable for people who run for 30 minutes as it has a lower pulse spike rate
# No-fat diet is quite suitable for people who run for 15 minutes as it has a lower pulse spike rate
# People who follow a low-fat diet have a lower pulse rate(30) while resting for a minute compared to those(40) who follow a no-fat diet
# People who follow a low-fat diet have a lower pulse rate(40) while walking for 30 minutes compared to those who follow a no-fat diet
# No-fat diet is suitable for most of them who rest and walk for different durations(as low-fat some pulse rate has lower values 30,40)
