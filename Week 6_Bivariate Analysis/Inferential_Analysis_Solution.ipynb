# %%
import pandas as pd

# %%
dataset=pd.read_csv("Placement.csv")
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
dataset=dataset.drop(columns="sl_no")
dataset
# Out:
#     gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p   degree_t  \
# 0        M  67.00   Others  91.00   Others  Commerce     58.00   Sci&Tech
# 1        M  79.33  Central  78.33   Others   Science     77.48   Sci&Tech
# 2        M  65.00  Central  68.00  Central      Arts     64.00  Comm&Mgmt
# 3        M  56.00  Central  52.00  Central   Science     52.00   Sci&Tech
# 4        M  85.80  Central  73.60  Central  Commerce     73.30  Comm&Mgmt
# ..     ...    ...      ...    ...      ...       ...       ...        ...
# 210      M  80.60   Others  82.00   Others  Commerce     77.60  Comm&Mgmt
# 211      M  58.00   Others  60.00   Others   Science     72.00   Sci&Tech
# 212      M  67.00   Others  67.00   Others  Commerce     73.00  Comm&Mgmt
# 213      F  74.00   Others  66.00   Others  Commerce     58.00  Comm&Mgmt
# 214      M  62.00  Central  58.00   Others   Science     53.00  Comm&Mgmt
#
#     workex  etest_p specialisation  mba_p      status    salary
# ...

# %% [markdown]
# # 1. Replace NAN values with correct value. And justify why you have chosen the same

# %%
# check the NAN values in each column
dataset.isna().sum()
# Out:
# gender             0
# ssc_p              0
# ssc_b              0
# hsc_p              0
# hsc_b              0
# hsc_s              0
# degree_p           0
# degree_t           0
# workex             0
# etest_p            0
# specialisation     0
# mba_p              0
# status             0
# salary            67
# dtype: int64

# %%
# Check if there is Nan values in any column and displaying the repective rows related to Nan values using isna().any()
# Here 67 rows which has Nan values in salary column got displayed

# %%
nan_rows = dataset[dataset.isna().any(axis=1)]
nan_rows
# Out:
#     gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p   degree_t  \
# 3        M   56.0  Central   52.0  Central   Science     52.00   Sci&Tech
# 5        M   55.0   Others   49.8   Others   Science     67.25   Sci&Tech
# 6        F   46.0   Others   49.2   Others  Commerce     79.00  Comm&Mgmt
# 9        M   58.0  Central   70.0  Central  Commerce     61.00  Comm&Mgmt
# 12       F   47.0  Central   55.0   Others   Science     65.00  Comm&Mgmt
# ..     ...    ...      ...    ...      ...       ...       ...        ...
# 198      F   67.0  Central   70.0  Central  Commerce     65.00     Others
# 201      M   54.2  Central   63.0   Others   Science     58.00  Comm&Mgmt
# 206      M   41.0  Central   42.0  Central   Science     60.00  Comm&Mgmt
# 208      F   43.0  Central   60.0   Others   Science     65.00  Comm&Mgmt
# 214      M   62.0  Central   58.0   Others   Science     53.00  Comm&Mgmt
#
#     workex  etest_p specialisation  mba_p      status  salary
# ...

# %%
# checking the placement status of the missing values to replace them with appropriate value
nan_rows_Not_Placed = dataset[dataset['salary'].isna() & (dataset['status']=='Not Placed')]
nan_rows_Not_Placed
# here all the missing values have placement status as "Not Placed"
# Out:
#     gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p   degree_t  \
# 3        M   56.0  Central   52.0  Central   Science     52.00   Sci&Tech
# 5        M   55.0   Others   49.8   Others   Science     67.25   Sci&Tech
# 6        F   46.0   Others   49.2   Others  Commerce     79.00  Comm&Mgmt
# 9        M   58.0  Central   70.0  Central  Commerce     61.00  Comm&Mgmt
# 12       F   47.0  Central   55.0   Others   Science     65.00  Comm&Mgmt
# ..     ...    ...      ...    ...      ...       ...       ...        ...
# 198      F   67.0  Central   70.0  Central  Commerce     65.00     Others
# 201      M   54.2  Central   63.0   Others   Science     58.00  Comm&Mgmt
# 206      M   41.0  Central   42.0  Central   Science     60.00  Comm&Mgmt
# 208      F   43.0  Central   60.0   Others   Science     65.00  Comm&Mgmt
# 214      M   62.0  Central   58.0   Others   Science     53.00  Comm&Mgmt
#
#     workex  etest_p specialisation  mba_p      status  salary
# ...

# %%
# replacing the nan values with 0 as they are not placed
# We can't replace them with median or mean, as it is not appropriate(as they are "not placed") 
dataset.fillna({"salary":0},inplace=True)

# %%
#checking if all the nan values are replaced in the dataset
dataset.isna().sum()
# Out:
# gender            0
# ssc_p             0
# ssc_b             0
# hsc_p             0
# hsc_b             0
# hsc_s             0
# degree_p          0
# degree_t          0
# workex            0
# etest_p           0
# specialisation    0
# mba_p             0
# status            0
# salary            0
# dtype: int64

# %%
dataset
# Out:
#     gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p   degree_t  \
# 0        M  67.00   Others  91.00   Others  Commerce     58.00   Sci&Tech
# 1        M  79.33  Central  78.33   Others   Science     77.48   Sci&Tech
# 2        M  65.00  Central  68.00  Central      Arts     64.00  Comm&Mgmt
# 3        M  56.00  Central  52.00  Central   Science     52.00   Sci&Tech
# 4        M  85.80  Central  73.60  Central  Commerce     73.30  Comm&Mgmt
# ..     ...    ...      ...    ...      ...       ...       ...        ...
# 210      M  80.60   Others  82.00   Others  Commerce     77.60  Comm&Mgmt
# 211      M  58.00   Others  60.00   Others   Science     72.00   Sci&Tech
# 212      M  67.00   Others  67.00   Others  Commerce     73.00  Comm&Mgmt
# 213      F  74.00   Others  66.00   Others  Commerce     58.00  Comm&Mgmt
# 214      M  62.00  Central  58.00   Others   Science     53.00  Comm&Mgmt
#
#     workex  etest_p specialisation  mba_p      status    salary
# ...

# %% [markdown]
# # 2. How many of them are not placed?

# %%
# Counting the number of students Not placed using sum() and assigning it to count_not_placed variable

# %%
count_not_placed=(dataset["status"]=="Not Placed").sum()
print(count_not_placed)
# Out:
# 67

# %%
# retrieving the rows with "Not placed" status from the dataset

# %%
dataset_not_placed=dataset[dataset['status']=='Not Placed']
dataset_not_placed
# Out:
#     gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p   degree_t  \
# 3        M   56.0  Central   52.0  Central   Science     52.00   Sci&Tech
# 5        M   55.0   Others   49.8   Others   Science     67.25   Sci&Tech
# 6        F   46.0   Others   49.2   Others  Commerce     79.00  Comm&Mgmt
# 9        M   58.0  Central   70.0  Central  Commerce     61.00  Comm&Mgmt
# 12       F   47.0  Central   55.0   Others   Science     65.00  Comm&Mgmt
# ..     ...    ...      ...    ...      ...       ...       ...        ...
# 198      F   67.0  Central   70.0  Central  Commerce     65.00     Others
# 201      M   54.2  Central   63.0   Others   Science     58.00  Comm&Mgmt
# 206      M   41.0  Central   42.0  Central   Science     60.00  Comm&Mgmt
# 208      F   43.0  Central   60.0   Others   Science     65.00  Comm&Mgmt
# 214      M   62.0  Central   58.0   Others   Science     53.00  Comm&Mgmt
#
#     workex  etest_p specialisation  mba_p      status  salary
# ...

# %%
dataset.describe()
# Out:
#             ssc_p       hsc_p    degree_p     etest_p       mba_p  \
# count  215.000000  215.000000  215.000000  215.000000  215.000000
# mean    67.303395   66.333163   66.370186   72.100558   62.278186
# std     10.827205   10.897509    7.358743   13.275956    5.833385
# min     40.890000   37.000000   50.000000   50.000000   51.210000
# 25%     60.600000   60.900000   61.000000   60.000000   57.945000
# 50%     67.000000   65.000000   66.000000   71.000000   62.000000
# 75%     75.700000   73.000000   72.000000   83.500000   66.255000
# max     89.400000   97.700000   91.000000   98.000000   77.890000
#
#               salary
# count     215.000000
# mean   198702.325581
# std    154780.926716
# min         0.000000
# 25%         0.000000
# 50%    240000.000000
# 75%    282500.000000
# max    940000.000000

# %%
from Univariate import Univariate

# %%
# separate quan and qual columns from the dataset
quan,qual=Univariate.quanqual(dataset)
print(quan)
print(qual)
# Out:
# ['ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary']
# ['gender', 'ssc_b', 'hsc_b', 'hsc_s', 'degree_t', 'workex', 'specialisation', 'status']

# %%
#Univariate analysis of the given dataset
descriptive=Univariate.univariate(dataset,quan)
descriptive
# Out:
#                ssc_p       hsc_p   degree_p     etest_p      mba_p  \
# Mean       67.303395   66.333163  66.370186   72.100558  62.278186
# Median          67.0        65.0       66.0        71.0       62.0
# Mode            62.0        63.0       65.0        60.0       56.7
# Q1:25%          60.6        60.9       61.0        60.0     57.945
# Q2:50%          67.0        65.0       66.0        71.0       62.0
# Q3:75%          75.7        73.0       72.0        83.5     66.255
# 99%             87.0       91.86      83.86        97.0    76.1142
# Q4:100%         89.4        97.7       91.0        98.0      77.89
# IQR             15.1        12.1       11.0        23.5       8.31
# 1.5rule        22.65       18.15       16.5       35.25     12.465
# Lower          37.95       42.75       44.5       24.75      45.48
# Upper          98.35       91.15       88.5      118.75      78.72
# Min            40.89        37.0       50.0        50.0      51.21
# ...

# %%
# check outliers on the quantitative columns
lower,upper=Univariate.outliercolumns(quan,descriptive)
print(lower)
print(upper)
# Out:
# ['hsc_p']
# ['hsc_p', 'degree_p', 'salary']

# %%
descriptive=Univariate.replaceoutliers(dataset,descriptive,lower,upper,quan)
descriptive
# Out:
#                ssc_p       hsc_p   degree_p     etest_p      mba_p  \
# Mean       67.303395   66.334744  66.358558   72.100558  62.278186
# Median          67.0        65.0       66.0        71.0       62.0
# Mode            62.0        63.0       65.0        60.0       56.7
# Q1:25%          60.6        60.9       61.0        60.0     57.945
# Q2:50%          67.0        65.0       66.0        71.0       62.0
# Q3:75%          75.7        73.0       72.0        83.5     66.255
# 99%             87.0      91.129      83.86        97.0    76.1142
# Q4:100%         89.4       91.15       88.5        98.0      77.89
# IQR             15.1        12.1       11.0        23.5       8.31
# 1.5rule        22.65       18.15       16.5       35.25     12.465
# Lower          37.95       42.75       44.5       24.75      45.48
# Upper          98.35       91.15       88.5      118.75      78.72
# Min            40.89       42.75       50.0        50.0      51.21
# ...

# %%
# check outliers on the quantitative columns
lower,upper=Univariate.outliercolumns(quan,descriptive)
print(lower)
print(upper)
# Out:
# []
# []

# %%
dataset
# Out:
#     gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p   degree_t  \
# 0        M  67.00   Others  91.00   Others  Commerce     58.00   Sci&Tech
# 1        M  79.33  Central  78.33   Others   Science     77.48   Sci&Tech
# 2        M  65.00  Central  68.00  Central      Arts     64.00  Comm&Mgmt
# 3        M  56.00  Central  52.00  Central   Science     52.00   Sci&Tech
# 4        M  85.80  Central  73.60  Central  Commerce     73.30  Comm&Mgmt
# ..     ...    ...      ...    ...      ...       ...       ...        ...
# 210      M  80.60   Others  82.00   Others  Commerce     77.60  Comm&Mgmt
# 211      M  58.00   Others  60.00   Others   Science     72.00   Sci&Tech
# 212      M  67.00   Others  67.00   Others  Commerce     73.00  Comm&Mgmt
# 213      F  74.00   Others  66.00   Others  Commerce     58.00  Comm&Mgmt
# 214      M  62.00  Central  58.00   Others   Science     53.00  Comm&Mgmt
#
#     workex  etest_p specialisation  mba_p      status    salary
# ...

# %% [markdown]
# # 3. find the reason for non placement from the dataset?

# %%
# analysing all the numerical columns by calculating mean with respect to status
mean_by_status=dataset.groupby(['status']).mean(numeric_only=True)
mean_by_status
# Out:
#                 ssc_p      hsc_p   degree_p    etest_p      mba_p  \
# status
# Not Placed  57.544030  58.598358  61.134179  69.587910  61.612836
# Placed      71.721486  69.837027  68.723649  73.238041  62.579392
#
#                    salary
# status
# Not Placed       0.000000
# Placed      287076.013514

# %%
# here we can neglect salary column  as we dont have value for them when the status is not placed
# Reason for not placed based on the numerical columns(marks)
# Mean of the placed and not placed doesn't vary much for mba_p column
# Mean of the have difference for placed and not placed status for other columns 
# observations on marks for not being placed:
# Students who got avg marks of 57% to 70% in SSC_P are not being placed
# students who got avg marks of 58% to 68% in hsc_p are not being placed
# students who got avg marks of 61% to 67% in degree_p are not being placed
# students who got avg marks of 70% to 72% in etest_p are not being placed

# %%
# Analysing the reason for non placement in the dataset
# analysing each categorical columns with placement status
# gender column with placement status
# grouping the data by gender and status wise using groupby and size() is used to count the number of person gender and status wise
# unstack() is used to display the results in tabular format
genderwise_result = dataset.groupby(['gender','status']).size().unstack()
print("Placement count-gender wise")
print( genderwise_result)
# Out:
# Placement count-gender wise
# status  Not Placed  Placed
# gender
# F               28      48
# M               39     100

# %%
# as per above out of 76 women 48 are placed and 28 are not placed(36% are not placed)
# out of 139 men, 100 are placed and 39 are not placed(28% are not placed)

# %%
# Gender wise-placement status plot
# countplot is used to count the number of occurence for each gender and status 
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(8,6))
sns.countplot(x='gender', hue='status', data=dataset)
plt.title('placement status by gender')
plt.xlabel('gender')
plt.ylabel('Count')
plt.show()

# %%
# ssc_b column with placed and not placed status
ssc_b_result = dataset.groupby(['ssc_b','status']).size().unstack()
print("Placement count-ssc_b wise")
print( ssc_b_result)
# Out:
# Placement count-ssc_b wise
# status   Not Placed  Placed
# ssc_b
# Central          38      78
# Others           29      70

# %%
# out of 116 in SSC_b(Central), 38 are not placed.
#i.e. 32% are not placed
# out of 99 in SSC_b(Others), 29 are not placed
#i.e 30% are not placed

# %%
# ssc_b wise-placement status plot
plt.figure(figsize=(8,6))
sns.countplot(x='ssc_b', hue='status', data=dataset)
plt.title('placement status by ssc_b')
plt.xlabel('ssc_b')
plt.ylabel('Count')
plt.show()

# %%
# hsc_b wise placement status
hsc_b_wise_result = dataset.groupby(["hsc_b","status"]).size().unstack(fill_value=0)
print(hsc_b_wise_result)
# Out:
# status   Not Placed  Placed
# hsc_b
# Central          27      57
# Others           40      91

# %%
# Out of 84 in HSC_B(Central), 27 students are not placed. i.e 32% are not placed
# Out of 131 in HSC_B(Others), 40 students are not placed. i.e 31% are not placed

# %%
# hsc_b wise placement plot
plt.figure(figsize=(8,6))
sns.countplot(x='hsc_b', hue='status',data=dataset)
plt.title("placement status by hsc_b")
plt.xlabel("hsc_b")
plt.ylabel("count")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#hsc_s based placement status
hsc_s_wise_result=dataset.groupby(['hsc_s','status']).size().unstack()
print(hsc_s_wise_result)
# Out:
# status    Not Placed  Placed
# hsc_s
# Arts               5       6
# Commerce          34      79
# Science           28      63

# %%
# Out of 11 in hsc_s(Arts) 5 are not placed. i.e 45% are not placed
# Out of 113 in hsc_s(Commerce), 34 are not placed.i.e. 30% are not placed
# Out of 91 in hsc_s(science), 28 are not placed.i.e . 30% are not placed

# %%
#hsc_s based placement status plot
plt.figure(figsize=(8,6))
sns.countplot(x='hsc_s',hue='status',data=dataset)
plt.xlabel('hsc_s_placement')
plt.ylabel('count')
plt.show()

# %%
# degree_t wise placement status
degree_t_wise_result=dataset.groupby(['degree_t','status']).size().unstack()
print(degree_t_wise_result)
# Out:
# status     Not Placed  Placed
# degree_t
# Comm&Mgmt          43     102
# Others              6       5
# Sci&Tech           18      41

# %%
# Out of 145 in degree_t(Comm&Mgmt), 43 are not placed. i.e 30% are not placed.
# Out of 11 in degree_t(Others), 6 are not placed. i.e. 45% are not placed.
# Out of 59 in degree_t(Sci&Tech), 18 are not placed. i.e.31% are not placed

# %%
# degree_t wise placement status plot
plt.figure(figsize=(8,6))
sns.countplot(x="degree_t",hue='status',data=dataset)
plt.title("degree wise plcement status")
plt.xlabel("degree_t")
plt.ylabel("count")
plt.show()

# %%
# workexp wise placemet status
workexp_wise_result=dataset.groupby(["workex","status"]).size().unstack()
print(workexp_wise_result)
# Out:
# status  Not Placed  Placed
# workex
# No              57      84
# Yes             10      64

# %%
# Out of 184 in workex(no), 57 students are not placed. i.e. 40% are not placed.
# Out of 74 in workex(yes), 10 students are not placed. i.e. 14% are not placed.

# %%
# workexp wise placement status plot
plt.figure(figsize=(8,6))
sns.countplot(x="workex",hue="status",data=dataset)
plt.title("workexp wise placement status")
plt.xlabel("workexperience")
plt.ylabel("count")
plt.show()

# %%
# specialisation wise placement status
specialisation_wise_result=dataset.groupby(["specialisation","status"]).size().unstack()
print(specialisation_wise_result)
# Out:
# status          Not Placed  Placed
# specialisation
# Mkt&Fin                 25      95
# Mkt&HR                  42      53

# %%
# Out of 120 in specialisation(Mkt&Fin), 25 students are not placed. i.e. 21% are not placed.
# Out of 95 in specialisation(Mkt&Hr), 42 students are not placed. i.e. 44% are not placed

# %%
# specialisation wise placement status plot
plt.figure(figsize=(8,6))
sns.countplot(x="specialisation",hue="status",data=dataset)
plt.title("specialisation wise placement status")
plt.xlabel("specialisation")
plt.ylabel("count")
plt.show()

# %%
# Overall observations for not being placed:
# Students who got average marks from 57% to 70% in SSC_P are unlikely to get placed
# students who got average marks from 58% to 68% in hsc_p are unlikely to get placed
# students who got average marks from 61% to 67% in degree_p are unlikely to get placed
# students who got average marks from 70% to 72% in etest_p are unlikely to get placed
# Women are likely not getting placed compared to men 
# Central board students in SSC_B are less likely to get placed compared to other boards.
# Central board students in HSC_B are less likely to get placed compared to others.
# Students from the arts in Hsc_s are less likely to get placed compared to commerce and science.
# Students from Other degrees are less likely to get placed compared to Comm&Mgmt and Sci&Tech.
# Students without work experience(workex) are less likely to get placed compared to students with work experience.
# Students with Mkt and HR specialisation are less likely to get placed compared to students with Mkt & Fin specialisation

# %% [markdown]
# # 4. What kind of relation between salary and mba_p?

# %%
# Create a scatter plot between Mba marks and salary
plt.figure(figsize=(8, 6))  # Set the figure size
sns.scatterplot(x="mba_p", y="salary", data=dataset, color="blue", marker="o")

# Add labels and title
plt.title("Scatter Plot of Mba_p vs Salary", fontsize=16)
plt.xlabel("Mba Marks", fontsize=12)
plt.ylabel("Salary", fontsize=12)

# Show the plot
plt.grid(True)  # Add grid for better readability
plt.show()

# %%
# Here data points which has salary as '0' are related to not placed students
# There is zero/no correlation between mba marks and salary
# when marks are increased,salary is not constantly getting increased/decreased. There is no particular relationship between mba marks and salary

# %%
sns.set(style="whitegrid")  # Set the style of the plot
plt.figure(figsize=(8, 5))  # Set the figure size
sns.lineplot(x="mba_p", y="salary", data=dataset, marker="o", color="green")
plt.title("mba marks vs salary", fontsize=16)
plt.xlabel("mba marks", fontsize=12)
plt.ylabel("Salary", fontsize=12)
plt.show()

# %% [markdown]
# # 5.Which specialization is getting minimum salary

# %%
def find_specialisation_min_salary(dataset):
    # Filter only placed students
    placed_students = dataset[dataset['status'] == "Placed"]

    # Find the minimum salary among placed students
    min_salary = placed_students['salary'].min()
    print("Minimum salary of the placed students is", min_salary)

    # Filter rows with that minimum salary
    min_salary_rows = placed_students[placed_students['salary'] == min_salary]
     
    # Print specialization and salary for each matching row
    print("Specialization with their respective salary:")
    for specialisation, salary in zip(min_salary_rows['specialisation'], min_salary_rows['salary']):
        print(f"{specialisation} - ₹{salary}")

# %%
find_specialisation_min_salary(dataset)
# Out:
# Minimum salary of the placed students is 200000.0
# Specialization with their respective salary:
# Mkt&Fin - ₹200000.0
# Mkt&Fin - ₹200000.0
# Mkt&Fin - ₹200000.0
# Mkt&HR - ₹200000.0
# Mkt&HR - ₹200000.0
# Mkt&HR - ₹200000.0

# %%
# There are totally 6 students, 3 each from Mkt&Fin and Mkt&HR got minimum salary(i.e.200000)
# Students with both the specialization are likely to get minimum salary

# %% [markdown]
# # 6. How many of them getting above 500000 salary?

# %%
def find_students_with_greater_salary(dataset):
    salary_greater_500000 = dataset[dataset["salary"] > 500000]
    number_of_students_greater_500000=len(salary_greater_500000)
    return salary_greater_500000, number_of_students_greater_500000

# %%
salary_greater_500000,number_of_students=find_students_with_greater_salary(dataset)
print("Number of students getting salary greater than 500000 are", number_of_students)
salary_greater_500000
# Out:
# Number of students getting salary greater than 500000 are 3
#     gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p   degree_t  \
# 119      M   60.8  Central  68.40  Central  Commerce      64.6  Comm&Mgmt
# 150      M   71.0  Central  58.66  Central   Science      58.0   Sci&Tech
# 177      F   73.0  Central  91.15   Others  Commerce      79.0  Comm&Mgmt
#
#     workex  etest_p specialisation  mba_p  status    salary
# 119    Yes    82.66        Mkt&Fin  64.34  Placed  706250.0
# 150    Yes    56.00        Mkt&Fin  61.30  Placed  690000.0
# 177    Yes    89.00        Mkt&Fin  70.81  Placed  650000.0

# %%
# 3 students are getting salary above 500000
# All of them belongs to Mkt&Fin specialization

# %% [markdown]
# # 7. Test the Analysis of Variance between etest_p and mba_p at signifance level 5%.(Make decision using Hypothesis Testing)

# %%
import scipy.stats as stats
stats.f_oneway(dataset["etest_p"],dataset['mba_p'])
# Out:
# F_onewayResult(statistic=np.float64(98.64487057324708), pvalue=np.float64(4.672547689133573e-21))

# %%
#H0: There is no significant difference between etest_p and mba_p marks of the students
#H1: There is significant difference between etest_p and mba_p marks of the students

# %%
#Reject null hypothesis: if p<0.05

# %%
# Here p-value is 0.000000000000000000004672<0.05
# Hence, reject null hypothesis(H0) and accept alternate hypothesis(H1)

# %% [markdown]
# # 8.Test the similarity between the degree_t(Sci&Tech) and specialisation(Mkt&HR) with respect to salary at significance level of 5%.(Make decision using Hypothesis Testing)

# %%
# Test whether salary of students with Degree(sci&Tech) and specialization(Mkt&HR) are similar
# Independent paired ttest. different group, same condition
from scipy.stats import ttest_ind
dataset=dataset.dropna()
degree_t= dataset[dataset["degree_t"]=="Sci&Tech"]["salary"]
specialisation= dataset[dataset["specialisation"]=="Mkt&HR"]["salary"]
ttest_ind(degree_t,specialisation)
# Out:
# TtestResult(statistic=np.float64(2.692041243555374), pvalue=np.float64(0.007897969943471179), df=np.float64(152.0))

# %%
# Null hypothesis: There is no similarity between salary of degree_t(Sci&Tech) and specialisation(Mkt&HR) students

# %%
# reject Null hypothesis: if p<0.05

# %%
# Here pvalue is 0.007 < 0.05
# Hence reject null hypothesis and accept alternate hypothesis

# %% [markdown]
# # 9. Convert the normal distribution to standard normal distribution for salary column

# %%
# Converting normal distribution to Standard normal distribution
# defining the function with function name stdNBgraph and dataset to be passed as parameter
def stdNBgraph(dataset):
# import seaborn library for plotting the graph    
    import seaborn as sns
# calculating the mean for the given column in the dataset using mean() function and assign it to mean variable
    mean=dataset.mean()
# calculating the standard deviation for the given column in the dataset using std() function and assigne it to std variable
    std=dataset.std()
# each values of particular column in dataset is store in list i and assigned to  list values    
    values = [i for i in dataset]
# z_score is calculated for each values in dataset and stored to list z_score    
    z_score =[((j-mean)/std) for j in values]
# density plot with respect to the given column in the dataset is plotted using distplot method by passing z_score as parameters
# kde=True so the curve is drawn in the plot    
    sns.distplot(z_score,kde=True)
# summation of the z_score divided by number of z_score values is calculated    
    (sum(z_score)/len(z_score))

# %%
stdNBgraph(dataset["salary"])
# Out:
# C:\Users\Inst_\AppData\Local\Temp\ipykernel_16328\3457753936.py:16: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(z_score,kde=True)

# %% [markdown]
# # 10. What is the probability Density Function of the salary range from 700000 to 900000?

# %%
# function to display the probability density function for the given range
def get_pdf_probability(dataset,startrange,endrange):
#importing the required libraries for plotting the graph
    from matplotlib import pyplot
    from scipy.stats import norm
    import seaborn as sns
# using seaborn plotting the graph with distplot method
# kde=True so the curve for probability density plot
# color for curve is given as red using kde _kws attribute
# color for the histogram plot is given as green using color attribute
    ax=sns.distplot(dataset,kde=True,kde_kws={'color':"red"},color='Green')  
# vertical lines for startrange and endrange is drawn using axvline method of pyplot and color of the line is given as blue 
    pyplot.axvline(startrange,color='blue')
    pyplot.axvline(endrange,color='blue')
# generate a sample
    sample=dataset
# calculate the mean and standard deviation using  mean() and std() and assign it to sample_mean and sample_std variable    
    sample_mean=sample.mean()
    sample_std=sample.std()
# Formatting the mean and standard deviation upto 3 decimal and printing the same
    print('Mean=%.3f,Standard deviation=%.3f'%(sample_mean,sample_std))
# define the distribution
    dist=norm(sample_mean,sample_std)
# sample probabilities for a range of outcomes
# list named value is created, values of the list is generated between the given range(start and endrange by the user)  stored in the list named value and assigned back to list values    
    values=[value for value in range(startrange,endrange)] 
# adding print statement to compare with usual method of using for loop with 3 lines
   
# pdf method from dist class is used to calculate the probability for each value available in values list 
# and all the probability values are stored in probabilities list   
    probabilities=[float(dist.pdf(value)) for value in values]
#adding all the probabiltiy value of the given range and stored in to the variable prob  
    prob=(sum(probabilities))
#Printing the overall probability value from startrange to endrange provided by the user
    print("the area between range({},{}):{}".format(startrange,endrange,sum(probabilities)))
    return prob

# %%
get_pdf_probability(dataset["salary"],700000,900000)
# Out:
# C:\Users\Inst_\AppData\Local\Temp\ipykernel_16328\1469728213.py:11: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax=sns.distplot(dataset,kde=True,kde_kws={'color':"red"},color='Green')
# Mean=197615.116,Standard deviation=150305.844
# the area between range(700000,900000):0.00041378126638300913
# 0.00041378126638300913

# %% [markdown]
# # 11. Test the similarity between the degree_t(Sci&Tech)with respect to etest_p and mba_p at significance level of 5%.(Make decision using Hypothesis Testing)

# %%
#Test whether etest_p and mba_p marks are similar for students with degree-sci&Tech
from scipy.stats import ttest_rel
dataset=dataset.dropna()
etest_p=dataset[dataset["degree_t"]=="Sci&Tech"]["etest_p"]
mba_p=dataset[dataset["degree_t"]=="Sci&Tech"]["mba_p"]
ttest_rel(etest_p,mba_p)
# Out:
# TtestResult(statistic=np.float64(5.0049844583693615), pvalue=np.float64(5.517920600505392e-06), df=np.int64(58))

# %%
# Null hypothesis: There is no similarity between etest_p and mba_p marks of students with degree-sci&Tech

# %%
# Reject Null hypothesis: if p<0.05

# %%
# here pvalue is 0.0000055179<0.05
# hence reject the null hypothesis and accept alternate hypothesis

# %% [markdown]
# # 12. Which parameter is highly correlated with salary?

# %%
dataset.corr(numeric_only = True)
# Out:
#              ssc_p     hsc_p  degree_p   etest_p     mba_p    salary
# ssc_p     1.000000  0.513478  0.538686  0.261993  0.388478  0.558475
# hsc_p     0.513478  1.000000  0.434606  0.240775  0.348452  0.459424
# degree_p  0.538686  0.434606  1.000000  0.227147  0.402376  0.423762
# etest_p   0.261993  0.240775  0.227147  1.000000  0.218055  0.186775
# mba_p     0.388478  0.348452  0.402376  0.218055  1.000000  0.141417
# salary    0.558475  0.459424  0.423762  0.186775  0.141417  1.000000

# %% [markdown]
# # 13. plot any useful graph and explain it.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
corr_matrix=dataset.corr(numeric_only=True)
sns.heatmap(corr_matrix, cmap="YlGnBu", annot=True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Create a scatter plot between ssc_p marks and salary
plt.figure(figsize=(8, 6))  # Set the figure size
sns.scatterplot(x="ssc_p", y="salary", data=dataset, color="blue", marker="o")

# Add labels and title
plt.title("Scatter Plot of ssc_p vs Salary", fontsize=16)
plt.xlabel("ssc Marks", fontsize=12)
plt.ylabel("Salary", fontsize=12)

# Show the plot
plt.grid(True)  # Add grid for better readability
plt.show()

# %%
sns.set(style="whitegrid")  # Set the style of the plot
plt.figure(figsize=(8, 5))  # Set the figure size
sns.lineplot(x="ssc_p", y="salary", data=dataset, marker="o", color="green")
plt.title("ssc marks vs salary", fontsize=16)
plt.xlabel("ssc marks", fontsize=12)
plt.ylabel("Salary", fontsize=12)
plt.show()

# %%
# Here comparatively of all the columns, ssc marks are highly(0.558) correlated  with salary
